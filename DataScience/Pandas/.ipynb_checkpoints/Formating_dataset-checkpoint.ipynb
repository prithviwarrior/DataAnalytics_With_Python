# %% [markdown]
# # Assessment

# %%
import pandas as pd

# %%
df = pd.read_csv("Comcast_telecom_complaints_data.csv")

# %%
df
# Out:
#      Ticket #                                 Customer Complaint      Date  \
# 0      250635                      Comcast Cable Internet Speeds  22-04-15
# 1      223441       Payment disappear - service got disconnected  4/8/2015
# 2      242732                                  Speed and Service  18-04-15
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...  5/7/2015
# 4      307175         Comcast not working and no service to boot  26-05-15
# ...       ...                                                ...       ...
# 2219   213550                               Service Availability  4/2/2015
# 2220   318775         Comcast Monthly Billing for Returned Modem  6/2/2015
# 2221   331188                            complaint about comcast  6/9/2015
# 2222   360489             Extremely unsatisfied Comcast customer  23-06-15
# 2223   363614               Comcast, Ypsilanti MI Internet Speed  24-06-15
#
# ...

# %%
results = df.groupby("Status")

# %%
results

# %%
results.groups
# Out:
# {'Closed': [0, 1, 2, 8, 10, 11, 17, 18, 19, 27, 30, 36, 43, 44, 45, 46, 55, 56, 57, 58, 66, 67, 69, 71, 72, 73, 74, 75, 76, 77, 78, 81, 97, 98, 99, 130, 139, 141, 153, 158, 162, 164, 166, 168, 181, 184, 186, 193, 199, 201, 202, 203, 206, 207, 210, 211, 212, 215, 218, 220, 224, 230, 234, 239, 240, 241, 242, 243, 251, 254, 260, 261, 262, 266, 267, 268, 269, 271, 275, 284, 287, 288, 290, 291, 298, 300, 306, 308, 313, 314, 316, 320, 321, 322, 333, 340, 341, 344, 346, 349, ...], 'Open': [3, 9, 12, 23, 25, 26, 38, 39, 40, 41, 61, 65, 82, 84, 88, 89, 90, 96, 106, 112, 118, 125, 127, 131, 136, 137, 140, 150, 152, 155, 157, 165, 167, 169, 176, 185, 189, 190, 192, 195, 208, 219, 227, 228, 232, 233, 244, 245, 248, 249, 250, 253, 264, 270, 276, 279, 286, 303, 317, 324, 328, 332, 348, 359, 371, 401, 406, 429, 432, 442, 445, 450, 454, 459, 463, 489, 490, 492, 499, 513, 514, 520, 532, 548, 550, 560, 577, 579, 580, 581, 583, 590, 592, 595, 601, 602, 606, 618, 619, 622, ...], 'Pending': [6, 15, 29, 1
# ...

# %%
results.groups.keys()
# Out:
# dict_keys(['Closed', 'Open', 'Pending', 'Solved'])

# %%
for group, df in results:
    total_Closed = len(df[df["Status"]=="Closed"])
    total_Open = len(df[df["Status"]=="Open"])
    total_Pending = len(df[df["Status"]=="Pending"])
    total_Solved = len(df[df["Status"]=="Solved"])
    print("Closed:{}\nOpen:{}\nPending:{}\nSolved:{}".format(total_Closed, total_Open, total_Pending, total_Solved))
# Out:
# Closed:734
# Open:0
# Pending:0
# Solved:0
# Closed:0
# Open:363
# Pending:0
# Solved:0
# Closed:0
# Open:0
# Pending:154
# Solved:0
# Closed:0
# Open:0
# Pending:0
# Solved:973

# %%
for Status, df in results:
    print("{}:{}".format(Status,len(df)))
# Out:
# Closed:734
# Open:363
# Pending:154
# Solved:973

# %%
highest_case_state = df.groupby("State")

# %%
highest_case_state.groups.keys()
# Out:
# dict_keys(['Alabama', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District Of Columbia', 'District of Columbia', 'Florida', 'Georgia', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'Ohio', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia'])

# %%
l_states = []
l_cases = []
for Status, df in highest_case_state:
    print("{}:{}".format(Status,len(df)))
    #df["Case_count"] = len(df) 
    l_states.append(Status)
    l_cases.append(len(df))
# Out:
# Alabama:26
# Arizona:20
# Arkansas:6
# California:220
# Colorado:80
# Connecticut:12
# Delaware:12
# District Of Columbia:16
# District of Columbia:1
# Florida:240
# Georgia:288
# Illinois:164
# Indiana:59
# Iowa:1
# Kansas:2
# Kentucky:7
# Louisiana:13
# Maine:5
# Maryland:78
# Massachusetts:61
# Michigan:115
# Minnesota:33
# Mississippi:39
# Missouri:4
# Montana:1
# Nevada:1
# New Hampshire:12
# New Jersey:75
# New Mexico:15
# New York:6
# North Carolina:3
# Ohio:3
# Oregon:49
# Pennsylvania:130
# Rhode Island:1
# South Carolina:18
# Tennessee:143
# Texas:71
# Utah:22
# Vermont:3
# Virginia:60
# Washington:98
# West Virginia:11

# %%
new_df = pd.DataFrame(
    {
        "State" : l_states,
        "Cases" : l_cases
    }
)

# %%
new_df.sort_values(by='Cases', ascending=False)
# Out:
#                    State  Cases
# 10               Georgia    288
# 9                Florida    240
# 3             California    220
# 11              Illinois    164
# 36             Tennessee    143
# 33          Pennsylvania    130
# 20              Michigan    115
# 41            Washington     98
# 4               Colorado     80
# 18              Maryland     78
# 27            New Jersey     75
# 37                 Texas     71
# 19         Massachusetts     61
# 40              Virginia     60
# 12               Indiana     59
# 32                Oregon     49
# 22           Mississippi     39
# 21             Minnesota     33
# 0                Alabama     26
# 38                  Utah     22
# 1                Arizona     20
# 35        South Carolina     18
# 7   District Of Columbia     16
# 28            New Mexico     15
# 16             Louisiana     13
# 5            Connecticut     12
# 26         New Hampshire     12
# 6               Delaware     12
# ...

# %%
df
# Out:
#      Ticket #                                 Customer Complaint       Date  \
# 135    359224                                   Comcast monopoly   23-06-15
# 492    342392                               Lack of availability   15-06-15
# 598    275658                                    Comcast Service   5/6/2015
# 693    360281                                       ISP Data Cap   23-06-15
# 744    338283                                  monthly data caps  6/12/2015
# 745    373954                               Comcast Data Charges   30-06-15
# 761    363615                                    Overage Charges   24-06-15
# 800    360621                                          Data Caps   24-06-15
# 908    211904  Unable to get in touch with anyone that has th...   4/1/2015
# 909    278031             Comcast's data caps are anti-consumer.   5/7/2015
# 910    293104                                       HBOGO on PS4   16-05-15
# ...

# %%
'''
for Status, df in highest_case_state:
    df.sort_values(by='len(df)', ascending=False)
'''
# Out:
# "\nfor Status, df in highest_case_state:\n    df.sort_values(by='len(df)', ascending=False)\n"

# %%
l_states = []
l_cases_open = []
l_cases_closed = []
l_cases_pending = []
l_cases_solved = []
for State, df in highest_case_state:
    #print("{}:{}".format(Status,len(df))) 
    l_states.append(State)
    l_cases_open.append(len(df[df["Status"]=="Open"]))
    l_cases_closed.append(len(df[df["Status"]=="Closed"]))
    l_cases_pending.append(len(df[df["Status"]=="Pending"]))
    l_cases_solved.append(len(df[df["Status"]=="Solved"]))

# %%
new_df2 = pd.DataFrame(
    {
        "State" : l_states,
        "Open" : l_cases_open,
        "Closed" : l_cases_closed,
        "Pending" : l_cases_pending,
        "Solved" : l_cases_solved
    }
)

# %%
new_df2
# Out:
#                    State  Open  Closed  Pending  Solved
# 0                Alabama     4       8        5       9
# 1                Arizona     2       6        4       8
# 2               Arkansas     0       1        0       5
# 3             California    47      72       14      87
# 4               Colorado    12      23       10      35
# 5            Connecticut     2       3        1       6
# 6               Delaware     3       2        1       6
# 7   District Of Columbia     1       5        1       9
# 8   District of Columbia     0       0        0       1
# 9                Florida    35     100        4     101
# 10               Georgia    35      82       45     126
# 11              Illinois    23      57        6      78
# 12               Indiana     8      15        1      35
# 13                  Iowa     0       0        0       1
# 14                Kansas     0       1        1       0
# 15              Kentucky     0       1        3       3
# ...
