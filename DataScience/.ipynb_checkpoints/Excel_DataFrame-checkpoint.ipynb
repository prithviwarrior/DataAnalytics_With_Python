# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("marks.csv")

# %%
df
# Out:
#     ID    Name        Group   M1  M2  M3
# 0   10   Name0     Commerce   45  55  65
# 1   11   Name1        Maths   35  83  63
# 2   12   Name2     Commerce   60  47  58
# 3   13   Name3  Engineering   55  58  56
# 4   14   Name4  Engineering  100  45  47
# 5   15   Name5        Maths   83  85  58
# 6   16   Name6     Commerce   47  78  52
# 7   17   Name7  Engineering   34  70  36
# 8   18   Name8        Maths   25  53  63
# 9   19   Name9  Engineering   50  57  30
# 10  20  Name10     Commerce   55  37  34
# 11  21  Name11  Engineering   67  45  47
# 12  22  Name12        Maths   83  85  58
# 13  23  Name13     Commerce   47  53  52
# 14  24  Name14  Engineering   64  58  56
# 15  25  Name15        Maths   67  45  47
# 16  26  Name16        Maths   83  85  58
# 17  27  Name17     Commerce   47  53  12
# 18  28  Name18  Engineering   34  84  36
# 19  29  Name19  Engineering   25  53  63
# 20  30  Name20        Maths   90  90  80
# 21  31  Name21     Commerce   55  37  22
# ...

# %%
df["M1"] = df["M1"].astype(np.int16)

# %%
df.dtypes
# Out:
# ID        int64
# Name     object
# Group    object
# M1        int16
# M2        int64
# M3        int64
# dtype: object

# %%
df.rename(columns={"M1":"M11"}, inplace= True)

# %%
df
# Out:
#     ID    Name        Group  M11  M2  M3
# 0   10   Name0     Commerce   45  55  65
# 1   11   Name1        Maths   35  83  63
# 2   12   Name2     Commerce   60  47  58
# 3   13   Name3  Engineering   55  58  56
# 4   14   Name4  Engineering  100  45  47
# 5   15   Name5        Maths   83  85  58
# 6   16   Name6     Commerce   47  78  52
# 7   17   Name7  Engineering   34  70  36
# 8   18   Name8        Maths   25  53  63
# 9   19   Name9  Engineering   50  57  30
# 10  20  Name10     Commerce   55  37  34
# 11  21  Name11  Engineering   67  45  47
# 12  22  Name12        Maths   83  85  58
# 13  23  Name13     Commerce   47  53  52
# 14  24  Name14  Engineering   64  58  56
# 15  25  Name15        Maths   67  45  47
# 16  26  Name16        Maths   83  85  58
# 17  27  Name17     Commerce   47  53  12
# 18  28  Name18  Engineering   34  84  36
# 19  29  Name19  Engineering   25  53  63
# 20  30  Name20        Maths   90  90  80
# 21  31  Name21     Commerce   55  37  22
# ...

# %%
df["Total"] = df["M11"] + df["M2"] + df["M3"]

# %%
df
# Out:
#     ID    Name        Group  M11  M2  M3  Total
# 0   10   Name0     Commerce   45  55  65    165
# 1   11   Name1        Maths   35  83  63    181
# 2   12   Name2     Commerce   60  47  58    165
# 3   13   Name3  Engineering   55  58  56    169
# 4   14   Name4  Engineering  100  45  47    192
# 5   15   Name5        Maths   83  85  58    226
# 6   16   Name6     Commerce   47  78  52    177
# 7   17   Name7  Engineering   34  70  36    140
# 8   18   Name8        Maths   25  53  63    141
# 9   19   Name9  Engineering   50  57  30    137
# 10  20  Name10     Commerce   55  37  34    126
# 11  21  Name11  Engineering   67  45  47    159
# 12  22  Name12        Maths   83  85  58    226
# 13  23  Name13     Commerce   47  53  52    152
# 14  24  Name14  Engineering   64  58  56    178
# 15  25  Name15        Maths   67  45  47    159
# 16  26  Name16        Maths   83  85  58    226
# 17  27  Name17     Commerce   47  53  12    112
# 18  28  Name18  Engineering   34  84  36    154
# ...

# %%
df[(df["M11"] >= 35)&(df["M2"] >= 40)&(df["M3"] <= 90)]
# Out:
#     ID    Name        Group  M11  M2  M3  Total
# 0   10   Name0     Commerce   45  55  65    165
# 1   11   Name1        Maths   35  83  63    181
# 2   12   Name2     Commerce   60  47  58    165
# 3   13   Name3  Engineering   55  58  56    169
# 4   14   Name4  Engineering  100  45  47    192
# 5   15   Name5        Maths   83  85  58    226
# 6   16   Name6     Commerce   47  78  52    177
# 9   19   Name9  Engineering   50  57  30    137
# 11  21  Name11  Engineering   67  45  47    159
# 12  22  Name12        Maths   83  85  58    226
# 13  23  Name13     Commerce   47  53  52    152
# 14  24  Name14  Engineering   64  58  56    178
# 15  25  Name15        Maths   67  45  47    159
# 16  26  Name16        Maths   83  85  58    226
# 17  27  Name17     Commerce   47  53  12    112
# 20  30  Name20        Maths   90  90  80    260
# 22  32  Name22  Engineering  100  45  47    192
# 23  33  Name23        Maths   45  85  58    188

# %%
df2 = pd.DataFrame(
    {
        "A" : [1,2,3,4,5],
        "B" : [1,2,3,4,5]
    }
)

# %%
df2
# Out:
#    A  B
# 0  1  1
# 1  2  2
# 2  3  3
# 3  4  4
# 4  5  5

# %%
def mysum(data):
    print(data)

# %%
df.apply(mysum)
# Out:
# 0     10
# 1     11
# 2     12
# 3     13
# 4     14
# 5     15
# 6     16
# 7     17
# 8     18
# 9     19
# 10    20
# 11    21
# 12    22
# 13    23
# 14    24
# 15    25
# 16    26
# 17    27
# 18    28
# 19    29
# 20    30
# 21    31
# 22    32
# 23    33
# Name: ID, dtype: int64
# 0      Name0
# 1      Name1
# 2      Name2
# 3      Name3
# 4      Name4
# 5      Name5
# 6      Name6
# 7      Name7
# 8      Name8
# 9      Name9
# 10    Name10
# 11    Name11
# 12    Name12
# 13    Name13
# 14    Name14
# 15    Name15
# 16    Name16
# 17    Name17
# 18    Name18
# 19    Name19
# 20    Name20
# 21    Name21
# 22    Name22
# 23    Name23
# Name: Name, dtype: object
# 0        Commerce
# 1           Maths
# 2        Commerce
# 3     Engineering
# 4     Engineering
# 5           Maths
# 6        Commerce
# 7     Engineering
# 8           Maths
# 9     Engineering
# 10       Commerce
# 11    Engineering
# 12          Maths
# 13       Commerce
# 14    Engineering
# 15          Maths
# ...

# %%
'''
def checkResult(record):
    return "Fail" if record.min() < 35 else "Pass"
'''
# Out:
# '\ndef checkResult(record):\n    return "Fail" if record.min() < 35 else "Pass"\n'

# %%
df["result"] = df[["M11", "M2", "M3"]].apply(checkResult, axis=1)

# %%
df
# Out:
#     ID    Name        Group  M11  M2  M3  Total result
# 0   10   Name0     Commerce   45  55  65    165   Pass
# 1   11   Name1        Maths   35  83  63    181   Pass
# 2   12   Name2     Commerce   60  47  58    165   Pass
# 3   13   Name3  Engineering   55  58  56    169   Pass
# 4   14   Name4  Engineering  100  45  47    192   Pass
# 5   15   Name5        Maths   83  85  58    226   Pass
# 6   16   Name6     Commerce   47  78  52    177   Pass
# 7   17   Name7  Engineering   34  70  36    140   Fail
# 8   18   Name8        Maths   25  53  63    141   Fail
# 9   19   Name9  Engineering   50  57  30    137   Fail
# 10  20  Name10     Commerce   55  37  34    126   Fail
# 11  21  Name11  Engineering   67  45  47    159   Pass
# 12  22  Name12        Maths   83  85  58    226   Pass
# 13  23  Name13     Commerce   47  53  52    152   Pass
# 14  24  Name14  Engineering   64  58  56    178   Pass
# 15  25  Name15        Maths   67  45  47    159   Pass
# ...

# %%
#series = pd.series

# %%
def checkResult(record):
    #print(record.values)
    #return (record.min())
    return "Pass" if record.min() >=35 else "Fail"

# %%
df["result"] = df[["M11", "M2", "M3"]].apply(checkResult, axis=1)

# %%
df
# Out:
#     ID    Name        Group  M11  M2  M3  Total result
# 0   10   Name0     Commerce   45  55  65    165   Pass
# 1   11   Name1        Maths   35  83  63    181   Pass
# 2   12   Name2     Commerce   60  47  58    165   Pass
# 3   13   Name3  Engineering   55  58  56    169   Pass
# 4   14   Name4  Engineering  100  45  47    192   Pass
# 5   15   Name5        Maths   83  85  58    226   Pass
# 6   16   Name6     Commerce   47  78  52    177   Pass
# 7   17   Name7  Engineering   34  70  36    140   Fail
# 8   18   Name8        Maths   25  53  63    141   Fail
# 9   19   Name9  Engineering   50  57  30    137   Fail
# 10  20  Name10     Commerce   55  37  34    126   Fail
# 11  21  Name11  Engineering   67  45  47    159   Pass
# 12  22  Name12        Maths   83  85  58    226   Pass
# 13  23  Name13     Commerce   47  53  52    152   Pass
# 14  24  Name14  Engineering   64  58  56    178   Pass
# 15  25  Name15        Maths   67  45  47    159   Pass
# ...

# %%
df["result"] = df[["M11", "M2", "M3"]].apply(checkResult, axis=1)

# %%
df
# Out:
#     ID    Name        Group  M11  M2  M3  Total result
# 0   10   Name0     Commerce   45  55  65    165   Pass
# 1   11   Name1        Maths   35  83  63    181   Pass
# 2   12   Name2     Commerce   60  47  58    165   Pass
# 3   13   Name3  Engineering   55  58  56    169   Pass
# 4   14   Name4  Engineering  100  45  47    192   Pass
# 5   15   Name5        Maths   83  85  58    226   Pass
# 6   16   Name6     Commerce   47  78  52    177   Pass
# 7   17   Name7  Engineering   34  70  36    140   Fail
# 8   18   Name8        Maths   25  53  63    141   Fail
# 9   19   Name9  Engineering   50  57  30    137   Fail
# 10  20  Name10     Commerce   55  37  34    126   Fail
# 11  21  Name11  Engineering   67  45  47    159   Pass
# 12  22  Name12        Maths   83  85  58    226   Pass
# 13  23  Name13     Commerce   47  53  52    152   Pass
# 14  24  Name14  Engineering   64  58  56    178   Pass
# 15  25  Name15        Maths   67  45  47    159   Pass
# ...

# %%
def setResults(data):
    return data.sum(), "Fail" if(data.min() < 35) else "Pass" #two results are returned

# %%
df[["Total", "result"]] = df[["M11", "M2", "M3"]].apply(setResults, axis = 1, result_type="expand") #expand seperates the tuples

# %%
df
# Out:
#     ID    Name        Group  M11  M2  M3  Total result
# 0   10   Name0     Commerce   45  55  65    165   Pass
# 1   11   Name1        Maths   35  83  63    181   Pass
# 2   12   Name2     Commerce   60  47  58    165   Pass
# 3   13   Name3  Engineering   55  58  56    169   Pass
# 4   14   Name4  Engineering  100  45  47    192   Pass
# 5   15   Name5        Maths   83  85  58    226   Pass
# 6   16   Name6     Commerce   47  78  52    177   Pass
# 7   17   Name7  Engineering   34  70  36    140   Fail
# 8   18   Name8        Maths   25  53  63    141   Fail
# 9   19   Name9  Engineering   50  57  30    137   Fail
# 10  20  Name10     Commerce   55  37  34    126   Fail
# 11  21  Name11  Engineering   67  45  47    159   Pass
# 12  22  Name12        Maths   83  85  58    226   Pass
# 13  23  Name13     Commerce   47  53  52    152   Pass
# 14  24  Name14  Engineering   64  58  56    178   Pass
# 15  25  Name15        Maths   67  45  47    159   Pass
# ...

# %%
#df["M11"] = df["M11"].isnull()

# %%
#df["M11"]
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# Name: M11, dtype: bool

# %%
df.loc[(df["M11"]>= 35) & (df["M2"]>= 35) & (df["M3"]>=35), "Result"] = "Pass"

# %%
df.loc[df["Result"].isnull(), "Result"] = "Fail"

# %%
df
# Out:
#     ID    Name        Group  M11  M2  M3  Total result Result
# 0   10   Name0     Commerce   45  55  65    165   Pass   Pass
# 1   11   Name1        Maths   35  83  63    181   Pass   Pass
# 2   12   Name2     Commerce   60  47  58    165   Pass   Pass
# 3   13   Name3  Engineering   55  58  56    169   Pass   Pass
# 4   14   Name4  Engineering  100  45  47    192   Pass   Pass
# 5   15   Name5        Maths   83  85  58    226   Pass   Pass
# 6   16   Name6     Commerce   47  78  52    177   Pass   Pass
# 7   17   Name7  Engineering   34  70  36    140   Fail   Fail
# 8   18   Name8        Maths   25  53  63    141   Fail   Fail
# 9   19   Name9  Engineering   50  57  30    137   Fail   Fail
# 10  20  Name10     Commerce   55  37  34    126   Fail   Fail
# 11  21  Name11  Engineering   67  45  47    159   Pass   Pass
# 12  22  Name12        Maths   83  85  58    226   Pass   Pass
# 13  23  Name13     Commerce   47  53  52    152   Pass   Pass
# ...

# %% [markdown]
# # Assignment
# To check the number of students passed

# %%
def result_count(record):
    return 1 if record.item() == "Pass" else 0

# %%
df["result2"] = df[["result"]].apply(result_count, axis=1)

# %%
df
# Out:
#     ID    Name        Group  M11  M2  M3  Total result Result  result2
# 0   10   Name0     Commerce   45  55  65    165   Pass   Pass        1
# 1   11   Name1        Maths   35  83  63    181   Pass   Pass        1
# 2   12   Name2     Commerce   60  47  58    165   Pass   Pass        1
# 3   13   Name3  Engineering   55  58  56    169   Pass   Pass        1
# 4   14   Name4  Engineering  100  45  47    192   Pass   Pass        1
# 5   15   Name5        Maths   83  85  58    226   Pass   Pass        1
# 6   16   Name6     Commerce   47  78  52    177   Pass   Pass        1
# 7   17   Name7  Engineering   34  70  36    140   Fail   Fail        0
# 8   18   Name8        Maths   25  53  63    141   Fail   Fail        0
# 9   19   Name9  Engineering   50  57  30    137   Fail   Fail        0
# 10  20  Name10     Commerce   55  37  34    126   Fail   Fail        0
# 11  21  Name11  Engineering   67  45  47    159   Pass   Pass        1
# ...

# %%
Total_passed = sum(df["result2"])

# %%
Total_passed
# Out:
# 16
