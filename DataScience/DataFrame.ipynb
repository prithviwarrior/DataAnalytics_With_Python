# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(
    {
        "Slno"  : [1,2,3,4,5,6,7],
        "Name"  : ["name1", "name2", " name3", "name4", "name5", "name6","name7"],
        "M1"    : [34,56,78,55,66,35,45],
        "M2"    : [34,56,78,55,66,35,45],
        "M3"    : [34,56,78,55,66,35,45]
    }
)

# %%
df
# Out:
#    Slno    Name  M1  M2  M3
# 0     1   name1  34  34  34
# 1     2   name2  56  56  56
# 2     3   name3  78  78  78
# 3     4   name4  55  55  55
# 4     5   name5  66  66  66
# 5     6   name6  35  35  35
# 6     7   name7  45  45  45

# %%
df[1:3]
# Out:
#    Slno    Name  M1  M2  M3
# 1     2   name2  56  56  56
# 2     3   name3  78  78  78

# %%
df.loc[1:4, "M1"]
# Out:
# 1    56
# 2    78
# 3    55
# 4    66
# Name: M1, dtype: int64

# %%
df.loc[1:4,["M1", "M2"]]
# Out:
#    M1  M2
# 1  56  56
# 2  78  78
# 3  55  55
# 4  66  66

# %%
df.loc[ :,:]
# Out:
#    Slno    Name  M1  M2  M3
# 0     1   name1  34  34  34
# 1     2   name2  56  56  56
# 2     3   name3  78  78  78
# 3     4   name4  55  55  55
# 4     5   name5  66  66  66
# 5     6   name6  35  35  35
# 6     7   name7  45  45  45

# %%
df.index = list(range(10,17))

# %%
df
# Out:
#     Slno    Name  M1  M2  M3
# 10     1   name1  34  34  34
# 11     2   name2  56  56  56
# 12     3   name3  78  78  78
# 13     4   name4  55  55  55
# 14     5   name5  66  66  66
# 15     6   name6  35  35  35
# 16     7   name7  45  45  45

# %%
df["Name"]
# Out:
# 10     name1
# 11     name2
# 12     name3
# 13     name4
# 14     name5
# 15     name6
# 16     name7
# Name: Name, dtype: object

# %%
df[["Name","M1"]] #select M1,M2 from df
# Out:
#       Name  M1
# 10   name1  34
# 11   name2  56
# 12   name3  78
# 13   name4  55
# 14   name5  66
# 15   name6  35
# 16   name7  45

# %%
df.set_index("Slno" , inplace = True) #Slno will be index

# %%
df[2:5]
# Out:
#         Name  M1  M2  M3
# Slno
# 3      name3  78  78  78
# 4      name4  55  55  55
# 5      name5  66  66  66

# %%
#df.rename(columns, "Slno", "SlNo")

# %%
df
# Out:
#         Name  Marks1  M2  M3
# Slno
# 1      name1      34  34  34
# 2      name2      56  56  56
# 3      name3      78  78  78
# 4      name4      55  55  55
# 5      name5      66  66  66
# 6      name6      35  35  35
# 7      name7      45  45  45

# %%
df.loc[["name1","name2"],["M1","M2"]] #names is not index here
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-6f6a7afff267> in <module>
# ----> 1 df.loc[["name1","name2"],["M1","M2"]]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1051         # ugly hack for GH #836
#    1052         if self._multi_take_opportunity(tup):
# -> 1053             return self._multi_take(tup)
#    1054
#    1055         return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df.iloc[0, 1:3]
# Out:
# M1    34
# M2    34
# Name: 1, dtype: object

# %%
df.iloc[0:5, 1:3]
# Out:
#       M1  M2
# Slno
# 1     34  34
# 2     56  56
# 3     78  78
# 4     55  55
# 5     66  66

# %%
df.rename(columns={"M1":"Marks1"}, inplace=True)

# %%
df
# Out:
#         Name  Marks1  M2  M3
# Slno
# 1      name1      34  34  34
# 2      name2      56  56  56
# 3      name3      78  78  78
# 4      name4      55  55  55
# 5      name5      66  66  66
# 6      name6      35  35  35
# 7      name7      45  45  45

# %% [raw]
# reset_index()

# %%
df.reset_index()
# Out:
#    Slno    Name  Marks1  M2  M3
# 0     1   name1      34  34  34
# 1     2   name2      56  56  56
# 2     3   name3      78  78  78
# 3     4   name4      55  55  55
# 4     5   name5      66  66  66
# 5     6   name6      35  35  35
# 6     7   name7      45  45  45
